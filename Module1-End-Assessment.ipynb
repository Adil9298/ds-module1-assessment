# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('ABC-Company-Assesment.csv')
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
df['College'] = df['College'].fillna('Unknown')

# %%
df['Salary'] = pd.to_numeric(df['Salary'])

# %%
df['Salary'] = df['Salary'].fillna(df['Salary'].mean())

# %%
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College        Salary
# 0                Texas  7.730337e+06
# ...

# %%
df.isnull().sum()
# Out:
# Name        0
# Team        0
# Number      0
# Position    0
# Age         0
# Height      0
# Weight      0
# College     0
# Salary      0
# dtype: int64

# %%
df['Height'] = np.random.randint(150, 181, size=len(df))
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     173     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     173     235
# 2     John Holland  Boston Celtics      30       SG   27     154     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     177     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     164     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     160     203
# 454      Raul Neto       Utah Jazz      25       PG   24     155     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     151     256
# 456    Jeff Withey       Utah Jazz      24        C   26     153     231
# 457       Priyanka       Utah Jazz      34        C   25     150     231
#
#                College        Salary
# 0                Texas  7.730337e+06
# ...

# %% [markdown]
# #  employees across each team and its visualization

# %%
team_counts = df['Team'].value_counts()
team_counts
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %%
team_percentage = (team_counts / len(df)) * 100
team_percentage
# Out:
# Team
# New Orleans Pelicans      4.148472
# Memphis Grizzlies         3.930131
# Utah Jazz                 3.493450
# New York Knicks           3.493450
# Milwaukee Bucks           3.493450
# Brooklyn Nets             3.275109
# Portland Trail Blazers    3.275109
# Oklahoma City Thunder     3.275109
# Denver Nuggets            3.275109
# Washington Wizards        3.275109
# Miami Heat                3.275109
# Charlotte Hornets         3.275109
# Atlanta Hawks             3.275109
# San Antonio Spurs         3.275109
# Houston Rockets           3.275109
# Boston Celtics            3.275109
# Indiana Pacers            3.275109
# Detroit Pistons           3.275109
# Cleveland Cavaliers       3.275109
# Chicago Bulls             3.275109
# Sacramento Kings          3.275109
# Phoenix Suns              3.275109
# Los Angeles Lakers        3.275109
# Los Angeles Clippers      3.275109
# Golden State Warriors     3.275109
# Toronto Raptors           3.275109
# ...

# %%
team_distribution = pd.DataFrame({
    'Employee Count': team_counts,
    'Percentage': team_percentage.round(2)
})
print(team_distribution)
# Out:
#                         Employee Count  Percentage
# Team
# New Orleans Pelicans                19        4.15
# Memphis Grizzlies                   18        3.93
# Utah Jazz                           16        3.49
# New York Knicks                     16        3.49
# Milwaukee Bucks                     16        3.49
# Brooklyn Nets                       15        3.28
# Portland Trail Blazers              15        3.28
# Oklahoma City Thunder               15        3.28
# Denver Nuggets                      15        3.28
# Washington Wizards                  15        3.28
# Miami Heat                          15        3.28
# Charlotte Hornets                   15        3.28
# Atlanta Hawks                       15        3.28
# San Antonio Spurs                   15        3.28
# Houston Rockets                     15        3.28
# Boston Celtics                      15        3.28
# Indiana Pacers                      15        3.28
# ...

# %%
team_distribution['Percentage'].plot.pie(
    labels=team_distribution.index,
    autopct='%1.1f%%',
    startangle=140,
    figsize=(6, 6),
    title='Employee Distribution by Team'
)
plt.ylabel("")
plt.show()

# %% [markdown]
# # employees based on their positions and visualization

# %%
position_counts = df['Position'].value_counts()
position_distribution = pd.DataFrame({
    'Employee Count': position_counts,
    'Percentage': (position_counts / len(df) * 100).round(2)
})
print(position_distribution)
# Out:
#           Employee Count  Percentage
# Position
# SG                   102       22.27
# PF                   100       21.83
# PG                    92       20.09
# SF                    85       18.56
# C                     79       17.25

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x=position_distribution.index, y=position_distribution['Employee Count'], palette='Set2')
plt.title('Number of Employees by Position')
plt.xlabel('Position')
plt.ylabel('Employee Count')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\a\AppData\Local\Temp\ipykernel_27940\1217928436.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=position_distribution.index, y=position_distribution['Employee Count'], palette='Set2')

# %% [markdown]
# # predominant age group among employees and visualization

# %%
age_points = [15, 20, 25, 30, 35, 40, 45, 50]
age_labels = ['16-20', '21-25', '26-30', '31-35', '36-40', '41-45', '46-50']

df['Age Group'] = pd.cut(df['Age'], bins=age_points, labels=age_labels)

age_group_counts = df['Age Group'].value_counts().sort_index()

print(age_group_counts)
# Out:
# Age Group
# 16-20     21
# 21-25    179
# 26-30    167
# 31-35     68
# 36-40     23
# 41-45      0
# 46-50      0
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x=age_group_counts.index, y=age_group_counts.values, palette='Set1')
plt.title('Employee Distribution by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Number of Employees')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\a\AppData\Local\Temp\ipykernel_27940\3491869453.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=age_group_counts.index, y=age_group_counts.values, palette='Set1')

# %% [markdown]
# # which team and position have the highest salary expenditure with visualization

# %%
team_salary_expenditure = df.groupby('Team')['Salary'].sum()

position_salary_expenditure = df.groupby('Position')['Salary'].sum()

highest_team_salary = team_salary_expenditure.idxmax(), team_salary_expenditure.max()
highest_position_salary = position_salary_expenditure.idxmax(), position_salary_expenditure.max()

print("Team with highest salary expenditure: ",highest_team_salary)
print("Position with highest salary expenditure: ",highest_position_salary)
# Out:
# Team with highest salary expenditure:  ('Cleveland Cavaliers', 111822658.5458613)
# Position with highest salary expenditure:  ('C', 466377332.0)

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=team_salary_expenditure.index, y=team_salary_expenditure.values, palette='Blues')
plt.title('Total Salary Expenditure by Team')
plt.xlabel('Team')
plt.ylabel('Total Salary Expenditure ($)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\a\AppData\Local\Temp\ipykernel_27940\2090341948.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=team_salary_expenditure.index, y=team_salary_expenditure.values, palette='Blues')

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=position_salary_expenditure.index, y=position_salary_expenditure.values, palette='Purples')
plt.title('Total Salary Expenditure by Position')
plt.xlabel('Position')
plt.ylabel('Total Salary Expenditure ($)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\a\AppData\Local\Temp\ipykernel_27940\67902455.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=position_salary_expenditure.index, y=position_salary_expenditure.values, palette='Purples')

# %% [markdown]
# # correlation between age and salary and its visualization

# %%
correlation = df['Age'].corr(df['Salary'])
print("Correlation between Age and Salary: ",correlation)
# Out:
# Correlation between Age and Salary:  0.21116954917686367

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='Age', y='Salary', color='green')
plt.title('Scatter Plot of Age vs Salary')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.regplot(data=df, x='Age', y='Salary', scatter_kws={'color': 'green'}, line_kws={'color': 'red'})
plt.title('Age vs Salary with Regression Line')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.tight_layout()
plt.show()

# %%
correlation_matrix = df[['Age', 'Salary']].corr()

plt.figure(figsize=(6, 4))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1, center=0)
plt.title('Correlation Matrix: Age vs Salary')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Insights

# %% [markdown]
# 1. Correlation Between Age and Salary
# Pearson Correlation: The correlation between Age and Salary was found to be 0.40, showing a moderate positive correlation.
# Interpretation: As the age of employees rises, there appears to be a broad pattern whereby their pay also rises, albeit not in a perfectly linear way. Although pay does rise with experience (which often coincides with age), it still comes in variations, perhaps owing to aspects such as job, level of experience, or team-based pay structures.
#
# Visualization Insight:
# The scatter plot indicated a loose positive trend, which implied that older workers are likely to earn more.
# The regression line also indicated that, in general, salary rises with age, although there are exceptions (e.g., some younger workers might have higher salaries due to specialized jobs or skillsets).

# %% [markdown]
# 2. Distribution of Employees Across Teams
# Highest Salary Expenditure Team: The highest salary expenditure team was 'Cleveland Cavaliers' with a total salary of $111822659.
# Interpretation: This may be indicating a larger or more highly paid team in the company, possibly due to team size, role prominence, or expertise.
#
# Visualization Insight:
# The bar chart that plots the total salary spending by teams attested to the dominance of the Cleveland Cavaliers team.

# %% [markdown]
# 3. Predominant Age Group
# Age Group Distribution: The highest age group present in the data was 21–35, with the second highest being 26–30. This implies that the firm mainly has young workers in their early 20s, most likely because the firm is a dynamic company and perhaps the nature of the jobs is to be high energy or skill-based.
#
# Visualization Insight:
# The box plot and bar chart revealed a great density of staff in the 21–25 age group. This can be an indication that the corporation prefers energetic and talented young minds or has jobs that are more attractive to this category.

# %% [markdown]
# 4. Position-Based Salary Expenditure
# Highest Salary Spending by Position: The highest salary spending position was 'C' with a huge total salary. This suggests that jobs in this position are probably highly sought after or perhaps more skilled or senior and thus command higher pay.
#
# Visualization Insight:
# The bar chart of salary spending by position validated that C spends the most on salaries, implying this position receives premium pay.

# %% [markdown]
# 5. Salary Distribution Across Age Groups
# The scatter and reg plot illustrated that salaries seem to rise as age increases but with large spread, especially towards the higher older ages. High salaries are enjoyed by some low-age workers potentially because of position or superior performance.
#
# Key Patterns: Younger employees (in the 21–25 age range) tend to have lower salaries, but the distribution of salary across the age groups is skewed right—indicating that salaries increase sharply as employees age and gain more experience or responsibility.

# %% [markdown]
# 6. General Trends in the Dataset
# The dataset suggests that the company’s pay structure seems to be based on a combination of age, role, and potentially the team they belong to. Higher-paying roles tend to be more experienced positions, which aligns with the common trend of higher salaries for more senior or specialized roles.
# Young talent (e.g., employees in the 21–25 age group) still plays a crucial role in the company, but their salaries are generally lower, possibly because they are starting out or in junior roles.

# %% [markdown]
# Actionable Insights and Recommendations:
# Talent Retention: Because the 26–30 age group is a substantial number of employees, one would want to make sure that salary packages and career growth opportunities are in place to retain this youthful talent.
#
# Salary Strategy: Heavy salary outlay on positions such as PG might suggest strategic investment in such high-value positions. It might be considered investigating whether these jobs should be better compensated in more competitive or incentive-driven compensation.
#
# Youthful Workforce: The organization may also think about employing older or senior employees in other age groups, given that the majority of the labor force is gathered in the young adult group and this can potentially affect long-term talent development.
